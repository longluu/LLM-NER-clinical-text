# %% [markdown]
# # MedMentions

# %% [markdown]
# ## Preprocessed data

# %%
import pandas as pd

df_data = pd.read_csv('../data/public/MedMentions/preprocessed-data/val.csv')

# %%
df_data.iloc[0, 0]
# Out:
# "['<START>', 'The', 'Impact', 'of', 'Deployment', 'on', 'Parental', ',', 'Family', 'and', 'Child', 'Adjustment', 'in', 'Military', 'Families', 'Since', '9', '/', '11', ',', 'military', 'service', 'in', 'the', 'United', 'States', 'has', 'been', 'characterized', 'by', 'wartime', 'deployments', 'and', 'reintegration', 'challenges', 'that', 'contribute', 'to', 'a', 'context', 'of', 'stress', 'for', 'military', 'families', '.', '<END>', '<START>', 'Research', 'indicates', 'the', 'negative', 'impact', 'of', 'wartime', 'deployment', 'on', 'the', 'well', 'being', 'of', 'service', 'members', ',', 'military', 'spouses', ',', 'and', 'children', '.', '<END>', '<START>', 'Yet', ',', 'few', 'studies', 'have', 'considered', 'how', 'parental', 'deployments', 'may', 'affect', 'adjustment', 'in', 'young', 'children', 'and', 'their', 'families', '.', '<END>', '<START>', 'Using', 'deployment', 'records', 'and', 'parent', '-', 'reported', 'measures', 'from', 'primary', 'caregiving', '(', 'N', '=', '680',
# ...

# %%
df_data.iloc[0, 1]
# Out:
# "['<START>', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-UMLS:C1550414', 'L-UMLS:C1550414', 'O', 'O', 'B-UMLS:C0041703', 'L-UMLS:C0041703', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-UMLS:C0038435', 'O', 'O', 'O', 'O', '<END>', '<START>', 'U-UMLS:C0035168', 'O', 'O', 'B-UMLS:C1513916', 'L-UMLS:C1513916', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-UMLS:C1550414', 'U-UMLS:C0680022', 'O', 'U-UMLS:C3245458', 'O', 'O', 'O', 'O', 'O', '<END>', '<START>', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '<END>', '<START>', 'O', 'B-UMLS:C0034869', 'L-UMLS:C0034869', 'O', 'O', 'O', 'U-UMLS:C0684224', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-UMLS:C3245458', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '<END>', '<START>', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 
# ...

# %%
pd.set_option('display.max_rows', None)
pd.DataFrame({'token': df_data.iloc[0, 0].split("', '"), 'UMLS': df_data.iloc[0, 1].split("', '"), 'entities': df_data.iloc[0, 2].split("', '")})
# Out:
#              token             UMLS   entities
# 0        ['<START>        ['<START>  ['<START>
# 1              The                O          O
# 2           Impact                O          O
# 3               of                O          O
# 4       Deployment                O          O
# 5               on                O          O
# 6         Parental                O          O
# 7                ,                O          O
# 8           Family                O          O
# 9              and                O          O
# 10           Child                O          O
# 11      Adjustment                O          O
# 12              in                O          O
# 13        Military                O          O
# 14        Families                O          O
# 15           Since                O          O
# 16               9                O          O
# 17               /                O          O
# 18              11                O          O
# ...
